# %% [markdown]
# # Loading Data with API's

# %% [markdown]
# An API (Application Programming interface) is an interface where users can access live data.

# %%
import requests
import pandas as pd

# %% [markdown]
# To get API to work, you need to register and obtain an authorization key.

# %%
api_url = "https://api.yelp.com/v3/businesses/search"

authorization = {

}

search_parameters = {
    'term' : 'restaurants',
    'location' : 'Ephraim, UT',
    'radius' : 150000,
    'limit' : 50
}

# Notes can be found on class GitHub page
