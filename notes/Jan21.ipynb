# %%
import numpy as np
import pandas as pd

# %%
countries = pd.read_csv('Datasets/countries-of-the-world.csv')
countries.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
def square(x):
    return x*x

print(square(2))
print(square(25))
# Out:
# 4
# 625

# %%
countries['GDP ($ per capita)'].apply(lambda x: x*x)
countries['GDP ($ per capita)'].apply(lambda row: row['Area (sq.mi.)'] / row['Population'], axis=1)

# Axis = 1 is for row
# Axis = 0 is for column
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 countries['GDP ($ per capita)'].apply(lambda x: x*x)
# ----> 2 countries['GDP ($ per capita)'].apply(lambda row: row['Area (sq.mi.)'] / row['Population'], axis=1)
#       4 # Axis = 1 is for row
#       5 # Axis = 0 is for column
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
# ...

# %% [markdown]
# # Loading Data into Pandas

# %%
import pandas as pd

grades = pd.read_csv('Datasets/grades.csv')

grades
# Out:
#       James Abbott       Good   87   Pass   100   93        76        85
# 0       Jane Baker       Good   92   Pass    95   97        84        82
# 1  George Costello   Adequate   83   Pass   100   91   missing        88
# 2      Susan Davis       Good   79   Pass   100   86        81        90
# 3    Jared Erikson    Perfect   96   Pass    85   90        87        79
# 4  Samantha Fisher       Fail   54   Fail    60   40        62   missing
# 5     Isaac Gibson   Adequate   76   Pass    95   89   missing        72
# 6   Emily Harrison       Good   88   Pass   100  100        93        81
# 7     Peter Ingram   Adequate   90   Fail   100   94        79        80
# 8  Michael Jackson    Perfect   89   Pass    95   99        84        87

# %%
grades = pd.read_csv('Datasets/grades.csv', header = None)

column_names = ['NAM', 'ATT', 'HON', 'PRP', 'PRC', 'PRF', 'MID', 'FIN']
grades = pd.read_csv('Datasets/grades.csv', header = None, names=column_names)
grades
# Out:
#                NAM        ATT  HON    PRP  PRC  PRF       MID       FIN
# 0     James Abbott       Good   87   Pass  100   93        76        85
# 1       Jane Baker       Good   92   Pass   95   97        84        82
# 2  George Costello   Adequate   83   Pass  100   91   missing        88
# 3      Susan Davis       Good   79   Pass  100   86        81        90
# 4    Jared Erikson    Perfect   96   Pass   85   90        87        79
# 5  Samantha Fisher       Fail   54   Fail   60   40        62   missing
# 6     Isaac Gibson   Adequate   76   Pass   95   89   missing        72
# 7   Emily Harrison       Good   88   Pass  100  100        93        81
# 8     Peter Ingram   Adequate   90   Fail  100   94        79        80
# 9  Michael Jackson    Perfect   89   Pass   95   99        84        87
